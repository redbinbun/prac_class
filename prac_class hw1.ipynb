# %% [markdown]
# <a href="https://colab.research.google.com/github/redbinbun/prac_class/blob/main/prac_class%20hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("tidyverse")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
filter(flights, month==1, day==1)%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
flights%>%filter(month==10&day==3)%>%head(4)
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    3   453      500            -7        636      648
# 2 2013 10    3   512      517            -5        739      757
# 3 2013 10    3   541      545            -4        826      855
# 4 2013 10    3   541      545            -4        920      933
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -12       US      1843   N177US  EWR    CLT   81       529     5     0
# 2 -18       UA       252   N594UA  EWR    IAH  186      1400     5    17
# 3 -29       AA      2243   N5ENAA  JFK    MIA  142      1089     5    45
# 4 -13       B6      1403   N547JB  JFK    SJU  194      1598     5    45
#   time_hour
# 1 2013-10-03 05:00:00
# 2 2013-10-03 05:00:00
# 3 2013-10-03 05:00:00
# 4 2013-10-03 05:00:00

# %%
flights%>%filter(month==1,day==1)%>%filter(dest=='ORD')%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   608      600             8        807      735
# 4 2013 1     1   629      630            -1        824      810
# 5 2013 1     1   656      700            -4        854      850
# 6 2013 1     1   709      700             9        852      832
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150      719      5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138      733      6     0
# 3 32        MQ      3768   N9EAMQ  EWR    ORD  139      719      6     0
# 4 14        AA       303   N3CYAA  LGA    ORD  140      733      6    30
# 5  4        AA       305   N4WNAA  LGA    ORD  143      733      7     0
# ...

# %%
flights%>%filter(month==1 & day==1 & dest%in% c('ORD', 'LAS'))%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   554      558            -4        740      728
# 2 2013 1     1   558      600            -2        753      745
# 3 2013 1     1   559      600            -1        854      902
# 4 2013 1     1   608      600             8        807      735
# 5 2013 1     1   629      630            -1        824      810
# 6 2013 1     1   651      655            -4        936      942
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 12        UA      1696   N39463  EWR    ORD  150       719     5    58
# 2  8        AA       301   N3ALAA  LGA    ORD  138       733     6     0
# 3 -8        UA      1187   N76515  EWR    LAS  337      2227     6     0
# 4 32        MQ      3768   N9EAMQ  EWR    ORD  139       719     6     0
# 5 14        AA       303   N3CYAA  LGA    ORD  140       733     6    30
# ...

# %%
arrange(flights, year, month, day)%>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
arrange(flights, desc(dep_delay))%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      9   641      900           1301      1242     1530
# 2 2013 6     15  1432     1935           1137      1607     2120
# 3 2013 1     10  1121     1635           1126      1239     1810
# 4 2013 9     20  1139     1845           1014      1457     2210
# 5 2013 7     22   845     1600           1005      1044     1815
# 6 2013 4     10  1100     1900            960      1342     2211
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 1272      HA        51   N384HA  JFK    HNL  640      4983      9    0
# 2 1127      MQ      3535   N504MQ  JFK    CMH   74       483     19   35
# 3 1109      MQ      3695   N517MQ  EWR    ORD  111       719     16   35
# 4 1007      AA       177   N338AA  JFK    SFO  354      2586     18   45
# 5  989      MQ      3075   N665MQ  JFK    CVG   96       589     16    0
# ...

# %%
select(flights, year, month, day)%>%head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, -(year:day))%>%head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# ...

# %%
select(flights, contains("arr"))%>%head()
# Out:
#   arr_time sched_arr_time arr_delay carrier
# 1  830      819            11       UA
# 2  850      830            20       UA
# 3  923      850            33       AA
# 4 1004     1022           -18       B6
# 5  812      837           -25       DL
# 6  740      728            12       UA

# %%
select(flights, starts_with("arr"))%>%head()
# Out:
#   arr_time arr_delay
# 1  830      11
# 2  850      20
# 3  923      33
# 4 1004     -18
# 5  812     -25
# 6  740      12

# %%
rename(flights, tail_num=tailnum)%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# ...

# %%
colnames(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
colnames(flights)[12]
# Out:
# [1] "tailnum"

# %% [markdown]
# # 새 섹션

# %%
colnames(flights)[12]='tail_num'

# %%
colnames(flights)[12]
# Out:
# [1] "tail_num"

# %%
select(flights, time_hour, arr_time, everything())%>%head()
# Out:
#   time_hour           arr_time year month day dep_time sched_dep_time dep_delay
# 1 2013-01-01 05:00:00  830     2013 1     1   517      515             2
# 2 2013-01-01 05:00:00  850     2013 1     1   533      529             4
# 3 2013-01-01 05:00:00  923     2013 1     1   542      540             2
# 4 2013-01-01 05:00:00 1004     2013 1     1   544      545            -1
# 5 2013-01-01 06:00:00  812     2013 1     1   554      600            -6
# 6 2013-01-01 05:00:00  740     2013 1     1   554      558            -4
#   sched_arr_time arr_delay carrier flight tailnum origin dest air_time distance
# 1  819            11       UA      1545   N14228  EWR    IAH  227      1400
# 2  830            20       UA      1714   N24211  LGA    IAH  227      1416
# 3  850            33       AA      1141   N619AA  JFK    MIA  160      1089
# 4 1022           -18       B6       725   N804JB  JFK    BQN  183      1576
# ...

# %%
new_flights<-flights%>%select(year:day, ends_with("delay"), distance, air_time)%>% mutate(gain=dep_delay-arr_delay, hours=air_time/60, gain_per_hour=gain/hours)

# %%
new_flights
# Out:
#        year month day dep_delay arr_delay distance air_time gain hours
# 1      2013 1     1    2         11       1400     227       -9  3.7833333
# 2      2013 1     1    4         20       1416     227      -16  3.7833333
# 3      2013 1     1    2         33       1089     160      -31  2.6666667
# 4      2013 1     1   -1        -18       1576     183       17  3.0500000
# 5      2013 1     1   -6        -25        762     116       19  1.9333333
# 6      2013 1     1   -4         12        719     150      -16  2.5000000
# 7      2013 1     1   -5         19       1065     158      -24  2.6333333
# 8      2013 1     1   -3        -14        229      53       11  0.8833333
# 9      2013 1     1   -3         -8        944     140        5  2.3333333
# 10     2013 1     1   -2          8        733     138      -10  2.3000000
# 11     2013 1     1   -2         -2       1028     149        0  2.4833333
# 12     2013 1     1   -2         -3       1005     158        1  2.6333333
# ...

# %%
flights%>%group_by(year, month, day)%>%summarise(delay=mean(dep_delay, na.rm=TRUE))%>%head()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %%
flights%>%group_by(origin)%>%summarise(delay=mean(dep_delay, na.rm=TRUE),
                                       delay_sd=sd(dep_delay, na.rm=TRUE),
                                      n=n())
# Out:
#   origin delay    delay_sd n
# 1 EWR    15.10795 41.32370 120835
# 2 JFK    12.11216 39.03507 111279
# 3 LGA    10.34688 39.99302 104662

# %%
flights%>%group_by(dest)%>%summarise(count=n(), dist=mean(distance, na.rm=TRUE), delay=mean(arr_delay, na.rm=TRUE))%>%filter(count>20, dest|="ATL")%>%head()
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:141: unexpected '='
# 1: flights%>%group_by(dest)%>%summarise(count=n(), dist=mean(distance, na.rm=TRUE), delay=mean(arr_delay, na.rm=TRUE))%>%filter(count>20, dest|=
#                                                                                                                                                 ^
# Traceback:

# %%
ggplot(data=mpg)+geom_point(mapping=aes(x=displ, y=hwy))
# Out:
# plot without title

# %%
ggplot(data=mpg, mapping=aes(x=displ, y=hwy))+geom_point()
# Out:
# plot without title

# %%
mpg%>%head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(data=mpg, mapping=aes(x=displ, y=hwy))+geom_point(mapping=aes(colour=cyl))+geom_smooth()+geom_line()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
ggplot(data=mpg, mapping=aes(x=displ, y=hwy))+geom_point()+geom_line()
# Out:
# plot without title

# %%
ggplot(data=mpg, mapping=aes(x=displ, y=hwy, color=class))+geom_point()
# Out:
# plot without title

# %%
ggplot(data=mpg, mapping=aes(x=displ, y=hwy, size=class))+geom_point()
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data=mpg)+geom_point(mapping=aes(x=displ, y=hwy))+facet_wrap(~class, nrow=2)
# Out:
# plot without title

# %%
ggplot(data=mpg)+geom_point(mapping=aes(x=displ, y=hwy))+facet_grid(drv~cyl)
# Out:
# plot without title

# %%
ggplot(data=mpg)+geom_point(mapping=aes(x=displ, y=hwy))+theme_bw()+theme(axis.line=element_line(size=.8, colour="black"), panel.grid.minor=element_blank(), panel.border=element_blank(), text=element_text(size=25))
# Out:
# plot without title

# %%
flights%>%head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
ggplot(data=flights)+geom_point(mapping=aes(x=air_time, y=distance, color=dep_delay ))
# Out:
# Warning message:
# “Removed 9430 rows containing missing values (geom_point).”
# plot without title
